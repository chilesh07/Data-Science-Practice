# %%
import pickle
import numpy as np
import joblib

# %%
pipe = joblib.load(r'C:\Users\chilesh\Desktop\Data science\project 4\credit_risk_model.pkl')

# %%
import pandas as pd

new_customer = {
    'person_age': 30,
    'person_income': 50000,
    'person_emp_length': 5,
    'loan_amnt': 10000,
    'loan_int_rate': 12.5,
    'cb_person_cred_hist_length': 6,
    'person_home_ownership': 'RENT',
    'loan_intent': 'EDUCATION',
    'loan_grade': 'B',
    'cb_person_default_on_file': 'N',
    'high_loan': 1,
    'long_credit_history': 7, 
    'income_per_age':7000.000, 
    'loan_income_ratio':0.25252, 
    'stable_employee':7,
    'bal_amt_incom_loan':40000, 
    'loan_percent_income':0.10
    
}

# %%
test_input = pd.DataFrame([new_customer])

# %%
pipe.predict(test_input)
# Out:
# array([1])
